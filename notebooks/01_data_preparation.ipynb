# %%
import pandas as pd
import os

# %%
df = pd.read_csv("../data/raw/clean_data.csv")

# %%
df.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0      1     1  2010-02-05      24924.50      False        42.31       2.572
# 1      1     2  2010-02-05      50605.27      False        42.31       2.572
# 2      1     3  2010-02-05      13740.12      False        42.31       2.572
# 3      1     4  2010-02-05      39954.04      False        42.31       2.572
# 4      1     5  2010-02-05      32229.38      False        42.31       2.572
#
#    MarkDown1  MarkDown2  MarkDown3  ...  Unemployment  Type    Size  \
# 0        0.0        0.0        0.0  ...         8.106     A  151315
# 1        0.0        0.0        0.0  ...         8.106     A  151315
# 2        0.0        0.0        0.0  ...         8.106     A  151315
# 3        0.0        0.0        0.0  ...         8.106     A  151315
# 4        0.0        0.0        0.0  ...         8.106     A  151315
#
#    Super_Bowl Labor_Day  Thanksgiving  Christmas  week  month  year
# ...

# %%
df_subset = df[df['Dept'].isin([i for i in range(10)])]

# %%
# Splitting data into Stores
store_dir = "../data/store_level_data_2/"
train_size = {}
for store in df_subset['Store'].unique():
    df_sub = df_subset[df_subset['Store'] == store]
    df_sub['Date'] = pd.to_datetime(df_sub['Date'])
    df_sub = df_sub.set_index("Date")
    path = os.path.join(store_dir,"store_" + str(store))
    os.makedirs(path)
    train = df_sub.loc[:'2012-05-01'].reset_index()
    valid = df_sub.loc['2012-05-02':'2012-08-01'].reset_index()
    test = df_sub.loc['2012-08-01':].reset_index()
    train_size[store] =  train.shape[0]
    train.to_csv(os.path.join(path, "train.csv"), index=False)
    valid.to_csv(os.path.join(path, "valid.csv"), index=False)
    test.to_csv(os.path.join(path, "test.csv"), index=False)
# Out:
# /var/folders/1q/26x3nv656dg2gv4xzbytws5m0000gn/T/ipykernel_10175/4170053012.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['Date'] = pd.to_datetime(df_sub['Date'])
# /var/folders/1q/26x3nv656dg2gv4xzbytws5m0000gn/T/ipykernel_10175/4170053012.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['Date'] = pd.to_datetime(df_sub['Date'])
# /var/folders/1q/26x3nv656dg2gv4xzbytws5m0000gn/T/ipykernel_10175/4170053012.py:6: SettingWithCopyWarning:
# ...

# %%
train_size
# Out:
# {1: 1053,
#  2: 1053,
#  3: 1053,
#  4: 1053,
#  5: 1052,
#  6: 1053,
#  7: 1053,
#  8: 1053,
#  9: 1053,
#  10: 1053,
#  11: 1053,
#  12: 1053,
#  13: 1053,
#  14: 1053,
#  15: 1053,
#  16: 1053,
#  17: 1053,
#  18: 1053,
#  19: 1053,
#  20: 1053,
#  21: 1053,
#  22: 1052,
#  23: 1053,
#  24: 1053,
#  25: 1052,
#  26: 1053,
#  27: 1053,
#  28: 1051,
#  29: 1053,
#  30: 1037,
#  31: 1053,
#  32: 1053,
#  33: 932,
#  34: 1053,
#  35: 1053,
#  36: 870,
#  37: 1047,
#  38: 1046,
#  39: 1053,
#  40: 1053,
#  41: 1053,
#  42: 938,
#  43: 976,
#  44: 1044,
#  45: 1053}
